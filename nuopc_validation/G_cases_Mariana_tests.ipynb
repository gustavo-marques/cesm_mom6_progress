# %% [markdown]
# ### NUOPC G cases with different ways of passing SW bands (c1 to c4)
#
# Message from Mariana:
#
# i have the two sandboxes for my test
# SMS_Vnuopc_Ld1.T62_t061.GMOM_JRA.cheyenne_intel.validate0/
# SMS_Vnuopc_Ld1.T62_t061.GMOM_JRA.cheyenne_intel.validate
# the validate0 is where i am sending the c1->c4 fluxes
# I also independently did a bunch of prints and the two are equivalent in the total sum (which is exactly what we expected)

# %%
# %matplotlib inline

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from mom6_tools.MOM6grid import MOM6grid
from mom6_tools.m6plot import xyplot
import warnings
warnings.filterwarnings("ignore")
# Out:
# Basemap module not found. Some regional plots may not function properly

# %%
scr = '/glade/scratch/mvertens/'
exps = ['SMS_Vnuopc_Ld1.T62_t061.GMOM_JRA.cheyenne_intel.validate0',
       'SMS_Vnuopc_Ld1.T62_t061.GMOM_JRA.cheyenne_intel.validate']
path1= scr + exps[0]+'/run/'
path2= scr + exps[1]+'/run/'

grd = MOM6grid(path1+exps[0]+'.mom6.static.nc')
# Out:
# MOM6 grid successfully loaded...

# %%
frc1 =  xr.open_mfdataset(path1+'ocean.mom6.frc_000*.nc',combine='by_coords')
frc2 =  xr.open_mfdataset(path2+'ocean.mom6.frc_000*.nc',combine='by_coords')

# %%
#frc1

# %% [markdown]
# ### heat content from mass added/removed

# %%
heat_content_lrunoff_1 = np.ma.masked_invalid(frc1.heat_content_lrunoff.mean(dim='time').values)
heat_content_frunoff_1 = np.ma.masked_invalid(frc1.heat_content_frunoff.mean(dim='time').values)
heat_content_lprec_1 = np.ma.masked_invalid(frc1.heat_content_lprec.mean(dim='time').values)
heat_content_fprec_1 = np.ma.masked_invalid(frc1.heat_content_fprec.mean(dim='time').values)
heat_content_cond_1 = np.ma.masked_invalid(frc1.heat_content_cond.mean(dim='time').values)
heat_content_vprec_1 = np.ma.masked_invalid(frc1.heat_content_vprec.mean(dim='time').values)
heat_content_icemelt_1 = np.ma.masked_invalid(frc1.heat_content_icemelt.mean(dim='time').values)
Heat_PmE_1 = np.ma.masked_invalid(frc1.Heat_PmE.mean(dim='time').values)
heat_content_all_1 = heat_content_lrunoff_1 + heat_content_frunoff_1 + heat_content_lprec_1 + \
                     heat_content_vprec_1 + heat_content_cond_1 + heat_content_icemelt_1 + heat_content_fprec_1

# %%
heat_content_lrunoff_2 = np.ma.masked_invalid(frc2.heat_content_lrunoff.mean(dim='time').values)
heat_content_frunoff_2 = np.ma.masked_invalid(frc2.heat_content_frunoff.mean(dim='time').values)
heat_content_lprec_2 = np.ma.masked_invalid(frc2.heat_content_lprec.mean(dim='time').values)
heat_content_fprec_2 = np.ma.masked_invalid(frc2.heat_content_fprec.mean(dim='time').values)
heat_content_cond_2 = np.ma.masked_invalid(frc2.heat_content_cond.mean(dim='time').values)
heat_content_vprec_2 = np.ma.masked_invalid(frc2.heat_content_vprec.mean(dim='time').values)
heat_content_icemelt_2 = np.ma.masked_invalid(frc2.heat_content_icemelt.mean(dim='time').values)
Heat_PmE_2 = np.ma.masked_invalid(frc2.Heat_PmE.mean(dim='time').values)
heat_content_all_2 = heat_content_lrunoff_2 + heat_content_frunoff_2 + heat_content_lprec_2 + \
                     heat_content_vprec_2 + heat_content_cond_2 + heat_content_icemelt_2 + heat_content_fprec_2

# %%
# %matplotlib inline

fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(26,12))
ax1 = ax.flatten()
plt.suptitle('validate0')

xyplot(heat_content_lrunoff_1, grd.geolon, grd.geolat, grd.area_t, title='lrunoff', 
       axis=ax1[0], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_frunoff_1, grd.geolon, grd.geolat, grd.area_t, title='frunoff', 
       axis=ax1[1], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_lprec_1, grd.geolon, grd.geolat, grd.area_t, title='lprec ', 
       axis=ax1[2], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_fprec_1, grd.geolon, grd.geolat, grd.area_t, title='fprec ', 
       axis=ax1[3], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_cond_1, grd.geolon, grd.geolat, grd.area_t, title='cond ', 
       axis=ax1[4], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_icemelt_1, grd.geolon, grd.geolat, grd.area_t, title='ice ', 
       axis=ax1[5], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_vprec_1, grd.geolon, grd.geolat, grd.area_t, title='vprec ', 
       axis=ax1[6], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(Heat_PmE_1, grd.geolon, grd.geolat, grd.area_t, title='Heat_PmE ', 
       axis=ax1[7], nbins=50, colormap=plt.cm.nipy_spectral)

# %%
# %matplotlib inline

fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(26,12))
ax1 = ax.flatten()
plt.suptitle('validate')

xyplot(heat_content_lrunoff_2, grd.geolon, grd.geolat, grd.area_t, title='lrunoff', 
       axis=ax1[0], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_frunoff_2, grd.geolon, grd.geolat, grd.area_t, title='frunoff', 
       axis=ax1[1], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_lprec_2, grd.geolon, grd.geolat, grd.area_t, title='lprec ', 
       axis=ax1[2], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_fprec_2, grd.geolon, grd.geolat, grd.area_t, title='fprec ', 
       axis=ax1[3], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_cond_2, grd.geolon, grd.geolat, grd.area_t, title='cond ', 
       axis=ax1[4], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_icemelt_2, grd.geolon, grd.geolat, grd.area_t, title='ice ', 
       axis=ax1[5], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(heat_content_vprec_2, grd.geolon, grd.geolat, grd.area_t, title='vprec ', 
       axis=ax1[6], nbins=50, colormap=plt.cm.nipy_spectral)
xyplot(Heat_PmE_2, grd.geolon, grd.geolat, grd.area_t, title='Heat_PmE ', 
       axis=ax1[7], nbins=50, colormap=plt.cm.nipy_spectral)

# %% [markdown]
# ### Heat content from coupler

# %%
net_heat_coupler_1 = np.ma.masked_invalid(frc1.net_heat_coupler.mean(dim='time').values)

# %%
net_heat_coupler_2 = np.ma.masked_invalid(frc2.net_heat_coupler.mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('Surface ocean heat flux from SW+LW+latent+sensible+seaice_melt_heat (via the coupler)')

xyplot(net_heat_coupler_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50, colormap=plt.cm.bwr)
xyplot(net_heat_coupler_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50, colormap=plt.cm.bwr)

# %% [markdown]
# ### Heat content from surface water

# %%
heat_content_surfwater_1 = np.ma.masked_invalid(frc1.heat_content_surfwater.mean(dim='time').values)

# %%
heat_content_surfwater_2 = np.ma.masked_invalid(frc2.heat_content_surfwater.mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('Heat content (relative to 0degC) of net water crossing ocean surface (frozen+liquid)')

xyplot(heat_content_surfwater_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50, colormap=plt.cm.bwr)
xyplot(heat_content_surfwater_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50, colormap=plt.cm.bwr)

# %% [markdown]
# ### Shortwave

# %%
sw_1 = np.ma.masked_invalid(frc1.SW.mean(dim='time').values)

# %%
sw_2 = np.ma.masked_invalid(frc2.SW.mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('Shortwave')

xyplot(sw_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50, colormap=plt.cm.bwr)
xyplot(sw_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50, colormap=plt.cm.bwr)

# %% [markdown]
# ### Longwave

# %%
lw_1 = np.ma.masked_invalid(frc1.LW.mean(dim='time').values)

# %%
lw_2 = np.ma.masked_invalid(frc2.LW.mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('Longwave')

xyplot(lw_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50, colormap=plt.cm.bwr)
xyplot(lw_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50, colormap=plt.cm.bwr)

# %% [markdown]
# ### Latent

# %%
lat_1 = np.ma.masked_invalid(frc1.latent.mean(dim='time').values)
lat_2 = np.ma.masked_invalid(frc2.latent.mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('Latent')

xyplot(lat_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50)
xyplot(lat_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50)

# %% [markdown]
# ### Sensible

# %%
sen_1 = np.ma.masked_invalid(frc1.sensible.mean(dim='time').values)
sen_2 = np.ma.masked_invalid(frc2.sensible.mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('Latent')

xyplot(sen_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50)
xyplot(sen_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50)

# %% [markdown]
# ### Seaice melt

# %%
ice_1 = np.ma.masked_invalid(frc1.seaice_melt_heat .mean(dim='time').values)
ice_2 = np.ma.masked_invalid(frc2.seaice_melt_heat .mean(dim='time').values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,5.5))
ax1 = ax.flatten()
plt.suptitle('seaice_melt_heat')

xyplot(ice_1, grd.geolon, grd.geolat, grd.area_t, title='validate0', 
       axis=ax1[0], nbins=50)
xyplot(ice_2, grd.geolon, grd.geolat, grd.area_t, title='validate', 
       axis=ax1[1], nbins=50)
