# %% [markdown]
# ### Modify the topography in the Denmark strait

# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from mom6_tools.MOM6grid import MOM6grid
from mom6_tools.m6plot import xyplot, yzplot 
from mom6_tools.m6toolbox import genBasinMasks
warnings.filterwarnings("ignore")
# Out:
# Basemap module not found. Some regional plots may not function properly

# %%
path = '/glade/scratch/gmarques/'
case = ['g.c2b6.GJRA.TL319_t061.long_JRA_mct.061']
grd = MOM6grid('/glade/scratch/gmarques/'+str(case[0])+'/run/'+str(case[0])+'.mom6.static.nc')
depth = grd.depth_ocean
# remote Nan's, otherwise genBasinMasks won't work
depth[np.isnan(depth)] = 0.0
basin_code = genBasinMasks(grd.geolon, grd.geolat, depth, xda=True)
# Out:
# MOM6 grid successfully loaded...
#
# 11.16427964664149 64.78854837178643 [391, 434]

# %% [markdown]
# ### Denmark strait topography

# %%
# %matplotlib inline
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,6))
xyplot(np.ma.masked_invalid(grd.depth_ocean), axis=ax, clim=(0,2500))
ax.set_xlim(385,400)
ax.set_ylim(382,397)
ax.set_title('tx0.6')
plt.grid()
