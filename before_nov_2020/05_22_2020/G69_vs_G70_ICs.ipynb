# %% [markdown]
# # Compare 69 vs 70
#
# ## Initial conditions
#
# **69**:
#
# WOA05 1 deg, 33 depth levels
#
# /glade/p/cesmdata/cseg/inputdata/ocn/mom/tx0.66v1/WOA05_pottemp_salt_180829.nc
#
# **70**:
#
# WOA13 0.25 deg, 103 depth levels
#
# /glade/work/fredc/cesm/hires/ic/woa13/ts_WOA13_Jan_IC_025deg_20171222.nc

# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from mom6_tools.MOM6grid import MOM6grid
from mom6_tools.m6plot import xyplot, yzplot 
from mom6_tools.m6toolbox import genBasinMasks
warnings.filterwarnings("ignore")
# Out:
# Basemap module not found. Some regional plots may not function properly

# %%
path = '/glade/scratch/gmarques/'
case = ['g.c2b6.GJRA.TL319_t061.long_JRA_mct.070']
grd_xr = MOM6grid('/glade/scratch/gmarques/'+str(case[0])+'/run/'+str(case[0])+'.mom6.static.nc',xrformat=True)

grd = MOM6grid('/glade/scratch/gmarques/'+str(case[0])+'/run/'+str(case[0])+'.mom6.static.nc')
depth = grd.depth_ocean
# remote Nan's, otherwise genBasinMasks won't work
depth[np.isnan(depth)] = 0.0
basin_code = genBasinMasks(grd.geolon, grd.geolat, depth, xda=True)
# Out:
# MOM6 grid successfully loaded...
#
# MOM6 grid successfully loaded...
#
# 11.16427964664149 64.78854837178643 [391, 434]

# %%
path = '/glade/scratch/gmarques/'
exps = ['g.c2b6.GJRA.TL319_t061.long_JRA_mct.069','g.c2b6.GJRA.TL319_t061.long_JRA_mct.070']
labels = ['G69','G70']

# %% [markdown]
# # Initial conditions

# %%
ic_mom1_t = xr.open_mfdataset(path+exps[0]+'/run/MOM_IC.nc')['Temp'].mean('Time').load()
ic_mom2_t = xr.open_mfdataset(path+exps[1]+'/run/MOM_IC.nc')['Temp'].mean('Time').load()
ic_mom1_s = xr.open_mfdataset(path+exps[0]+'/run/MOM_IC.nc')['Salt'].mean('Time').load()
ic_mom2_s = xr.open_mfdataset(path+exps[1]+'/run/MOM_IC.nc')['Salt'].mean('Time').load()

# %% [markdown]
# ## Difference in the initial T/S conditions at selected vertical levels

# %%
# %matplotlib inline
# change k indice to see bias at other depths
levels=[0,5,10,15,20,25,30,35,40,50,60]
for k in levels:
  fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,5))
  ax1 = ax.flatten()
  temp_mom1 = np.ma.masked_where(grd.depth_ocean < ic_mom1_t.Layer[k].values, np.ma.masked_invalid(ic_mom1_t[k,:].values))
  temp_mom2 = np.ma.masked_where(grd.depth_ocean < ic_mom1_t.Layer[k].values, np.ma.masked_invalid(ic_mom2_t[k,:].values))
  salt_mom1 = np.ma.masked_where(grd.depth_ocean < ic_mom1_t.Layer[k].values, np.ma.masked_invalid(ic_mom1_s[k,:].values))
  salt_mom2 = np.ma.masked_where(grd.depth_ocean < ic_mom1_t.Layer[k].values, np.ma.masked_invalid(ic_mom2_s[k,:].values))
    
  plt.suptitle(str(labels[1]+' - '+labels[0])+' at level {} or depth = {} m'.format(k, 
               ic_mom1_t.Layer[k].values))
  xyplot(temp_mom2-temp_mom1, grd.geolon, grd.geolat, grd.area_t, title='Initial temperature difference [C]', axis=ax1[0], 
         nbins=50, sigma=8)
  xyplot(salt_mom2-salt_mom1, grd.geolon, grd.geolat, grd.area_t, title='Initial salinity difference [psu]', axis=ax1[1], 
         nbins=50, sigma=8)

# %% [markdown]
# ## Zonally averaged initial T/S differences

# %%
# MOM
# reconstruct interfaces
elev_mom = np.concatenate([0,np.diff(ic_mom1_t.Layer).cumsum(),6000.], axis=None)
[_, z_mom] = np.meshgrid(ic_mom1_t.lath.values, -elev_mom)

mom1_temp_ic = xr.DataArray((ic_mom1_t.values) , dims=('z_l', 'yh','xh'), 
                             coords={'z_l':ic_mom1_t.Layer.values, 'yh': ic_mom1_t.lath.values, 'xh':ic_mom1_t.lonh.values})
mom1_salt_ic = xr.DataArray((ic_mom1_s.values), dims=('z_l', 'yh','xh'), 
                             coords={'z_l':ic_mom1_t.Layer.values, 'yh': ic_mom1_t.lath.values, 'xh':ic_mom1_t.lonh.values})

mom2_temp_ic = xr.DataArray((ic_mom2_t.values) , dims=('z_l', 'yh','xh'), 
                             coords={'z_l':ic_mom2_t.Layer.values, 'yh': ic_mom2_t.lath.values, 'xh':ic_mom2_t.lonh.values})
mom2_salt_ic = xr.DataArray((ic_mom2_s.values), dims=('z_l', 'yh','xh'), 
                             coords={'z_l':ic_mom2_t.Layer.values, 'yh': ic_mom2_t.lath.values, 'xh':ic_mom2_t.lonh.values})

# construct a 3D area with land values masked
area = np.ma.masked_where(grd.wet == 0,grd.area_t)
tmp = np.repeat(area[np.newaxis, :, :], len(ic_mom1_t.Layer), axis=0)
area3D = xr.DataArray(tmp, dims=('z_l', 'yh','xh'), 
                          coords={'z_l':ic_mom1_t.Layer.values, 'yh': ic_mom1_t.lath.values, 
                                  'xh':ic_mom1_t.lonh.values})
for k in range(len(area3D.z_l)):
    area3D[k,:] = grd_xr.area_t.where(grd_xr.depth_ocean >= area3D.z_l[k])

# %% [markdown]
# ### Global

# %%
mom1_temp_global_ic = ((mom1_temp_ic * area3D).sum('xh')/area3D.sum('xh'))
mom2_temp_global_ic = ((mom2_temp_ic * area3D).sum('xh')/area3D.sum('xh'))
mom1_salt_global_ic = ((mom1_salt_ic * area3D).sum('xh')/area3D.sum('xh'))
mom2_salt_global_ic = ((mom2_salt_ic * area3D).sum('xh')/area3D.sum('xh'))

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Global zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_global_ic), mom1_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_global_ic), mom2_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_global_ic-mom1_temp_global_ic), mom2_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-3, 3)); ax1[2].invert_yaxis()

# salt
yzplot(np.ma.masked_invalid(mom1_salt_global_ic), mom1_salt_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(29, 35.8), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_global_ic), mom2_salt_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(29, 35.8), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_global_ic-mom1_salt_global_ic), mom2_salt_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-1.5, 1.5)); ax1[5].invert_yaxis()

# %% [markdown]
# ### Atlantic

# %%
basin_code.sel(region='AtlanticOcean').where(grd_xr.wet==1).plot()

# %%
area3_alt = basin_code.sel(region='AtlanticOcean') * area3D
area3_alt = area3_alt.where(area3_alt>0)
mom1_temp_alt_ic = ((area3_alt*mom1_temp_ic).sum('xh')/area3_alt.sum('xh')).transpose()
mom1_salt_alt_ic = ((area3_alt*mom1_salt_ic).sum('xh')/area3_alt.sum('xh')).transpose()
mom2_temp_alt_ic = ((area3_alt*mom2_temp_ic).sum('xh')/area3_alt.sum('xh')).transpose()
mom2_salt_alt_ic = ((area3_alt*mom2_salt_ic).sum('xh')/area3_alt.sum('xh')).transpose()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Atlantic zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_alt_ic), mom1_temp_alt_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_alt_ic), mom2_temp_alt_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_alt_ic-mom1_temp_alt_ic), mom2_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-3, 3)); ax1[2].invert_yaxis()

# salt
yzplot(np.ma.masked_invalid(mom1_salt_alt_ic), mom1_salt_alt_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(32, 37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_alt_ic), mom2_salt_alt_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(32, 37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_alt_ic-mom1_salt_alt_ic), mom2_salt_alt_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-.5, .5)); ax1[5].invert_yaxis()

# %% [markdown]
# ### Pacific

# %%
basin_code.sel(region='PacificOcean').where(grd_xr.wet==1).plot()

# %%
area3_pac = basin_code.sel(region='PacificOcean') * area3D
area3_pac = area3_pac.where(area3_pac>0)

mom1_temp_pac_ic = ((area3_pac*mom1_temp_ic).sum('xh')/area3_pac.sum('xh')).transpose()
mom1_salt_pac_ic = ((area3_pac*mom1_salt_ic).sum('xh')/area3_pac.sum('xh')).transpose()
mom2_temp_pac_ic = ((area3_pac*mom2_temp_ic).sum('xh')/area3_pac.sum('xh')).transpose()
mom2_salt_pac_ic = ((area3_pac*mom2_salt_ic).sum('xh')/area3_pac.sum('xh')).transpose()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Pacific zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_pac_ic), mom1_temp_pac_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_pac_ic), mom2_temp_pac_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_pac_ic-mom1_temp_pac_ic), mom2_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-3, 3)); ax1[2].invert_yaxis()

# salt
yzplot(np.ma.masked_invalid(mom1_salt_pac_ic), mom1_salt_pac_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(32, 37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_pac_ic), mom2_salt_pac_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(32, 37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_pac_ic-mom1_salt_pac_ic), mom1_salt_pac_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-.5, .5)); ax1[5].invert_yaxis()

# %% [markdown]
# ### Med Sea

# %%
basin_code.sel(region='MedSea').where(grd_xr.wet==1).plot()

# %%
area3_med = basin_code.sel(region='MedSea') * area3D
area3_med = area3_med.where(area3_med>0)

mom1_temp_med_ic = ((area3_med*mom1_temp_ic).sum('xh')/area3_med.sum('xh')).transpose()
mom1_salt_med_ic = ((area3_med*mom1_salt_ic).sum('xh')/area3_med.sum('xh')).transpose()
mom2_temp_med_ic = ((area3_med*mom2_temp_ic).sum('xh')/area3_med.sum('xh')).transpose()
mom2_salt_med_ic = ((area3_med*mom2_salt_ic).sum('xh')/area3_med.sum('xh')).transpose()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Med Sea zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_med_ic), mom1_temp_med_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(8, 20), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()
ax1[0].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_temp_med_ic), mom2_temp_med_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(8, 20), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()
ax1[1].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_temp_med_ic-mom1_temp_med_ic), mom2_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-3, 3)); ax1[2].invert_yaxis()
ax1[2].set_xlim(30,48)
# salt
yzplot(np.ma.masked_invalid(mom1_salt_med_ic), mom1_salt_med_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(35, 39.2), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()
ax1[3].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_salt_med_ic), mom2_salt_med_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(35, 39.2), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()
ax1[4].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_salt_med_ic-mom1_salt_med_ic), mom2_salt_med_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-1, 1)); ax1[5].invert_yaxis()
ax1[5].set_xlim(30,48)
# Out:
# (30, 48)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14,4))
(area3_med*mom1_salt_med_ic/area3_med)[:,:,5].plot(ax=ax[0], vmin=34, vmax=39)
(area3_med*mom2_salt_med_ic/area3_med)[:,:,5].plot(ax=ax[1], vmin=34, vmax=39)

ax[0].set_xlim(-8,38);ax[0].set_ylim(29,48)
ax[1].set_xlim(-8,38);ax[1].set_ylim(29,48)
# Out:
# (29, 48)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14,4))
(area3_med*mom1_salt_med_ic/area3_med)[:,:,10].plot(ax=ax[0], vmin=34, vmax=39)
(area3_med*mom2_salt_med_ic/area3_med)[:,:,10].plot(ax=ax[1], vmin=34, vmax=39)

ax[0].set_xlim(-8,38);ax[0].set_ylim(29,48)
ax[1].set_xlim(-8,38);ax[1].set_ylim(29,48)
# Out:
# (29, 48)

# %%
# change k indice to see bias at other depths
levels=[0,5,10,15,20,25,30,35,40,50,60]
for k in levels:
  fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,5))
  ax1 = ax.flatten()
  temp_mom1 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom1_t[k,:].values))
  temp_mom2 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom2_t[k,:].values))
  salt_mom1 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom1_s[k,:].values))
  salt_mom2 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom2_s[k,:].values))
                                
  plt.suptitle(str(labels[1]+' - '+labels[0])+' at level {} or depth = {} m'.format(k, 
               ic_mom1_t.Layer[k].values))
  xyplot(temp_mom2 - temp_mom1, grd.geolon, grd.geolat, grd.area_t, title='Temperature difference [C]', axis=ax1[0], 
         nbins=50, sigma=8)
  xyplot(salt_mom2-salt_mom1, grd.geolon, grd.geolat, grd.area_t, title='Salinity difference [psu]', axis=ax1[1], 
         nbins=50, sigma=8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5e4dc4be8414> in <module>
#       4   fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18,5))
#       5   ax1 = ax.flatten()
# ----> 6   temp_mom1 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom1_t[k,:].values))
#       7   temp_mom2 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom2_t[k,:].values))
#       8   salt_mom1 = np.ma.masked_where(grd.depth_ocean < ds_mom1_t.zl[k].values, np.ma.masked_invalid(ds_mom1_s[k,:].values))
#
# NameError: name 'ds_mom1_t' is not defined

# %% [markdown]
# ## Zonally averaged T/S Bias

# %% [markdown]
# ### Global

# %%
area3D2 = area3D.rename({'z_l':'zl'})
mom1_temp_global = ((ds_mom1_t * area3D2).sum('xh')/area3D2.sum('xh'))
mom2_temp_global = ((ds_mom2_t * area3D2).sum('xh')/area3D2.sum('xh'))
mom1_salt_global = ((ds_mom1_s * area3D2).sum('xh')/area3D2.sum('xh'))
mom2_salt_global = ((ds_mom2_s * area3D2).sum('xh')/area3D2.sum('xh'))

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Global zonally-averaged T and S bias [C]')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_global), ds_mom1_t.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]+' - obs'), 
       axis=ax1[0], nbins=30, colormap=plt.cm.bwr, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_global), ds_mom2_t.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - obs'), 
       axis=ax1[1], nbins=30, colormap=plt.cm.bwr, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_global-mom1_temp_global), ds_mom2_t.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=30, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-0.4, 0.4))
ax1[2].invert_yaxis()
# salt
yzplot(np.ma.masked_invalid(mom1_salt_global), mom1_salt_global.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(29, 35.8), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_global), mom2_salt_global.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(29,35.8), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_global-mom1_salt_global), mom2_salt_global.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-0.1,0.1)); ax1[5].invert_yaxis()

# %% [markdown]
# ### Atlantic

# %%
area3_alt = basin_code.sel(region='AtlanticOcean') * area3D2
mom1_temp_alt = ((area3_alt*ds_mom1_t).sum('xh')/area3_alt.sum('xh')).transpose()
mom1_salt_alt = ((area3_alt*ds_mom1_s).sum('xh')/area3_alt.sum('xh')).transpose()
mom2_temp_alt = ((area3_alt*ds_mom2_t).sum('xh')/area3_alt.sum('xh')).transpose()
mom2_salt_alt = ((area3_alt*ds_mom2_s).sum('xh')/area3_alt.sum('xh')).transpose()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Atlantic zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_alt), mom1_temp_alt.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_alt), mom2_temp_alt.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_alt-mom1_temp_alt), mom2_temp_alt.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000]); ax1[2].invert_yaxis()

# salt
yzplot(np.ma.masked_invalid(mom1_salt_alt), mom1_salt_alt.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(32,37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_alt), mom2_salt_alt.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(32,37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_alt-mom1_salt_alt), mom2_salt_alt.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000]); ax1[5].invert_yaxis()

# %% [markdown]
# ### Pacific

# %%
area3_pac = basin_code.sel(region='PacificOcean') * area3D2
mom1_temp_pac = ((area3_pac*ds_mom1_t).sum('xh')/area3_pac.sum('xh')).transpose()
mom1_salt_pac = ((area3_pac*ds_mom1_s).sum('xh')/area3_pac.sum('xh')).transpose()
mom2_temp_pac = ((area3_pac*ds_mom2_t).sum('xh')/area3_pac.sum('xh')).transpose()
mom2_salt_pac = ((area3_pac*ds_mom2_s).sum('xh')/area3_pac.sum('xh')).transpose()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Pacific zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_pac), mom1_temp_pac.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_pac), mom2_temp_pac.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(-2, 28), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_temp_pac-mom1_temp_pac), mom2_temp_global_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-1, 1)); ax1[2].invert_yaxis()

# salt
yzplot(np.ma.masked_invalid(mom1_salt_pac), mom1_salt_pac.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(32, 37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_pac), mom2_salt_pac.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(32, 37), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()

yzplot(np.ma.masked_invalid(mom2_salt_pac-mom1_salt_pac), mom1_salt_pac.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-.1, .1)); ax1[5].invert_yaxis()

# %% [markdown]
# ### Med Sea

# %%
area3_med = basin_code.sel(region='MedSea') * area3D2
area3_med = area3_med.where(area3_med>0)
mom1_temp_med = ((area3_med*ds_mom1_t).sum('xh')/area3_med.sum('xh')).transpose()
mom1_salt_med = ((area3_med*ds_mom1_s).sum('xh')/area3_med.sum('xh')).transpose()
mom2_temp_med = ((area3_med*ds_mom2_t).sum('xh')/area3_med.sum('xh')).transpose()
mom2_salt_med = ((area3_med*ds_mom2_s).sum('xh')/area3_med.sum('xh')).transpose()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(25,12), sharex=True)
ax1 = ax.flatten()
plt.suptitle('Med Sea zonally-averaged T and S')

# temp
yzplot(np.ma.masked_invalid(mom1_temp_med), mom1_temp_med.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[0], nbins=50,clim=(8, 20), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[0].invert_yaxis()
ax1[0].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_temp_med), mom2_temp_med.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[1], nbins=50, clim=(8, 20), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[1].invert_yaxis()
ax1[1].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_temp_med-mom1_temp_med), mom2_temp_med.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[2], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-0.5, 0.5)); ax1[2].invert_yaxis()
ax1[2].set_xlim(30,48)
# salt
yzplot(np.ma.masked_invalid(mom1_salt_med), mom1_salt_med.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[0]), 
       axis=ax1[3], nbins=50,clim=(35, 39.2), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[3].invert_yaxis()
ax1[3].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_salt_med), mom2_salt_med.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]), 
       axis=ax1[4], nbins=50, clim=(35, 39.2), centerlabels=True, splitscale=[0, -1000,-6000]); ax1[4].invert_yaxis()
ax1[4].set_xlim(30,48)
yzplot(np.ma.masked_invalid(mom2_salt_med-mom1_salt_med), mom2_salt_med_ic.yh.values, z_mom, ylabel='Latitude', yunits='$^o$N', title=str(labels[1]+' - '+labels[0]), 
       axis=ax1[5], nbins=50, colormap=plt.cm.bwr, splitscale=[0, -1000,-6000], centerlabels=True, clim=(-0.5, 0.5)); ax1[5].invert_yaxis()
ax1[5].set_xlim(30,48)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14,4))
(area3_med*ds_mom1_s/area3_med)[:,:,0].plot(ax=ax[0], vmin=20, vmax=39)
(area3_med*ds_mom2_s/area3_med)[:,:,0].plot(ax=ax[1], vmin=20, vmax=39)

ax[0].set_xlim(-8,38);ax[0].set_ylim(29,48)
ax[1].set_xlim(-8,38);ax[1].set_ylim(29,48)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14,4))
(area3_med*ds_mom1_s/area3_med)[:,:,15].plot(ax=ax[0], vmin=20, vmax=39)
(area3_med*ds_mom2_s/area3_med)[:,:,15].plot(ax=ax[1], vmin=20, vmax=39)

ax[0].set_xlim(-8,38);ax[0].set_ylim(29,48)
ax[1].set_xlim(-8,38);ax[1].set_ylim(29,48)

# %% [markdown]
# # Salinity restoring comparison
#
# What we have been using so far (WOA05):
#
# /glade/p/cesmdata/cseg/inputdata/ocn/mom/tx0.66v1/salt_restore_tx0.66v1_180828.nc
#
# WOA13:
#
# /glade/work/gmarques/cesm/mom6_input_files/tx0.66v1/salinity_restoring/0.25/woa13*

# %%
import esmlab
# https://github.com/NCAR/esmlab
import esmlab_regrid            # https://github.com/NCAR/esmlab-regrid

# %%
gridpath = '/glade/work/gmarques/cesm/mom6_input_files/tx0.66v1/salinity_restoring'
esmlab.config.set({'regrid.gridfile-directory': gridpath})
# src and dst grids
src_grid_name = 'woa13_0.25_SCRIP'
dst_grid_name = 'tx0.66v1_SCRIP_190314'
# generate weights
R_bilinear = esmlab_regrid.regridder(name_grid_src=src_grid_name, name_grid_dst=dst_grid_name,
                            method='bilinear', overwrite_existing=False)

# %%
# old salinity file
s1 = xr.open_dataset('/glade/p/cesmdata/cseg/inputdata/ocn/mom/tx0.66v1/salt_restore_tx0.66v1_180828.nc')

# %%
months = ['01','02','03','04','05','06','07','08','09','10','11','12']

# %%
# %matplotlib inline

for m in range(len(months)):
  tmp = xr.open_dataset(gridpath+'/0.25/woa13_decav_s'+months[m]+'_04.nc', decode_times=False)
  tmp2 = R_bilinear(tmp.salt[0,0,:]).rename({'lat':'yh', 'lon':'xh'})
  woa13_salt_rem = tmp2.where(grd_xr.wet==1)
  fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(25,4))
  ax1 = ax.flatten()
  plt.suptitle('Month # {}'.format(months[m]))
  xyplot(np.ma.masked_invalid(s1.salt[m,:].values), grd.geolon, grd.geolat, grd.area_t, 
         title='SSS WOA05', axis=ax1[0], nbins=50, sigma=8)
  xyplot(np.ma.masked_invalid(woa13_salt_rem.values), grd.geolon, grd.geolat, grd.area_t, 
         title='SSS WOA13', axis=ax1[1], nbins=50, sigma=8)  
  xyplot(np.ma.masked_invalid(woa13_salt_rem.values-s1.salt[m,:].values), grd.geolon, grd.geolat, grd.area_t, 
         title='SSS WOA13 - WOA05', axis=ax1[2], nbins=50, sigma=10)
